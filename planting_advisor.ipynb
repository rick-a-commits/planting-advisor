# %%
from utils2 import get_geo_location
from utils2 import planting_advice
from IPython.display import Markdown, display

# %%
res, res_twi = planting_advice("Ghana", "Odonkwakrom", "Maize")

display(Markdown(res))
print("Translating...")
print(10*"*")
print("Translation Successful")
print(50*"*")
display(Markdown(res_twi))
# Out:
# The weather conditions for Odonkwakrom in Ghana for the last four weeks have generally been favorable, as this period aligns with the second rainy season experienced in this region of Ghana, which typically spans from September to November. Precipitation levels have been adequate, ensuring that the soil retains the moisture necessary for germination and initial growth of crops like maize. Temperatures have generally ranged from 20°C to 32°C, which is suitable for maize cultivation.
#
# For the next four weeks, forecasts suggest that these conditions will persist, with periodic rainfall and average temperatures remaining within the ideal range for maize growth. As we approach the end of the rainy season, there might be a gradual decrease in rainfall, which is normal for this time of year.
#
# Recommendation: It is a good time to plant maize in Odonkwakrom, Ghana.
#
# Reason for the recommendation: The geography and soil in Odonkwakrom, which is typical of the West African tropical climate, are conducive to maize cultivation due to their fertility. The current weather conditions, with adequate moisture from recent rains and supportive temperature ranges, enhance the suitability of this period for planting maize. Additionally, the typical planting window for maize in this area extends from April to June for the major season, and from September to November for the minor season. Planting now would still fall within this second planting window, allowing for an appropriate crop life cycle completion before the dry season sets in.
# Translating...
# **********
# Translation Successful
# **************************************************
# Osram a ɛda ho nsɛm a ɛyɛ Odonkwakrom mu, Ghana deɛ, anɔpa anɔpa mmerɛ ne nkɔmɔ kakra a atwam mmerɛ nan mu no, ɛyɛ ɔkwan pa ara, efisɛ saa bere yi yɛ mmere a ɛto so mmienu esrain no a Ghana mu ayɛ a ɛda so fi Ɛyɛbɔ (September) kɔ Ɔbɛtow (November). Nsuo a ɛbɔ no yɛ ade pa, ma ɔboɔ no tɔ na ɔmfa nsuo a ɛho hia ma abɔdeɛ a ɛyɛ aduan sɛ ɛyɛ mɔkɔ. Abɔdeɛ no yɛ nsɛm bi a ɛda ho, a ɔyɛ 20°C kɔ 32°C, a ɛyɛ papa ma mɔkɔ mmɔda ho.
#
# Mmere a ɛda so mu no, ɔkwan a ɛda ho nkɔmɔ da no, nsɛm da so ara bɛyɛ no sɛ nsuo bɛbɔ na abɔdeɛ a ɛyɛ a ɛdidi mu no bɛda so ara bɛyɛ pa ma mɔkɔ mmɔda ho. Sɛ yɛkɔ mfinimfini baabi a osram no reba mu no, ɛbɛyɛ sɛ nsuo a ɛbɔ no bɛyɛ dɔɔso kakra, a ɛyɛ ade a ɛyɛ nokware wɔ saa bere yi mu.
#
# Nkyerɛkyerɛ: Ɛyɛ bere pa ara sɛ yɛbɛyɛ mɔkɔ afirinhyia Odonkwakrom, Ghana.
#
# Nkyerɛkyerɛ a ɛma yɛyɛ yi: Ɛyɛ sɛ nsase ne abɔdeɛ a ɛda Odonkwakrom mu, a ɔyɛ a edi mmerɛbea a ɛda West Africa mmɔfra abatoɔ mu, yɛ nsa ahorow a ɛyɛ fɛ akwanama ma mɔkɔ mmɔda ho efisɛ wɔn ɔhoho. Osram a ɛda ho a ɛyɛ nsuo a ɛda ho a nsuo a ɛnni mmerɛ a ɛbɔ no ne abɔdeɛ a ɛyɛ fɛ no ka ho yɛ den. Saa ara na mmere no yɛ nokware ma mɔkɔ afirinhyia ho. Afei, mɔkɔ afirinhyia no mmere a ɛda Odonkwakrom mu yɛ fi Ɛbɔ (April) kɔ Ɔbɛtow (June) a ɛyɛ mmere kɛse na fi Ɛyɛbɔ (September) kɔ Ɔbɛtow (November) a ɛyɛ mmere ketewa. Afirinhyia a yɛyɛ nnɛ bɛyɛ abatoɔ yi mu, a ɛbɛma aduan a wɔaka ho bɛyɛ mmerɛden ansa na osram a ɛyɛ abɔda no nsi.
