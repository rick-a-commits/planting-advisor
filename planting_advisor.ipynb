# %%
from utils import get_geo_location
from utils import planting_advice
from IPython.display import Markdown, display

# %%
res, res_twi = planting_advice("Ghana", "Odonkwakrom", "Maize")

display(Markdown(res))
print("Translating...")
print(10*"*")
print("Translation Successful")
print(50*"*")
display(Markdown(res_twi))
# Out:
# The weather conditions for Odonkwakrom in Ghana for the last four weeks have been characterized by tropical conditions with frequent rain showers and relatively high humidity. Temperatures have consistently ranged from 23°C to 30°C, which are within the optimal growth range for maize. The rainfall has been moderate, providing adequate moisture levels necessary for the initial stages of maize growth.
#
# Looking forward, the forecast for the next four weeks suggests continued rainfall with occasional heavy showers and typical warm temperatures. This weather pattern indicates a suitable climate for maize cultivation, as maize thrives in warm and moderately wet conditions.
#
# Considering the geography and soil of the region, Odonkwakrom is located in a tropical zone with predominantly loamy soil, which provides good aeration, drainage, and nutrition. These soil conditions are generally appropriate for maize cultivation, supporting healthy root development and crop growth.
#
# Maize has a growth cycle of approximately 90 to 120 days, and in tropical regions like Ghana, maize can often be grown year-round due to the consistent temperature and rainfall. However, successful planting depends on aligning the crop development phases with predictable rainfall patterns to ensure adequate water availability, particularly during the critical germination and silking stages.
#
# Recommendation: It is currently a good time to plant maize in Odonkwakrom, Ghana. The weather and soil conditions are conducive, and the planting window has not been missed. Given the ongoing rainy season supplemented by warm temperatures, planting now aligns well with favorable growing conditions for maize. However, attention should be paid to potential heavy rainfall events that might necessitate drainage management to prevent waterlogging.
# Translating...
# **********
# Translation Successful
# **************************************************
# Osu no nsɛm a ɛfa ɔman Odonkwakrom wɔ Ghana ho a ɛda so mfe nan a atwa mu no, ɛda ho adi sɛ ɛyɛ nsuo da a ɛyɛ asase a ɛwɔ ɔwɔtwe mu a nsuo no da so. Nsuo no a ɛtɔ da no mu anaa nsuo a ɛnsa no de, ɔhaw no yɛ den, na ɛyɛ den ara a ɛda ho adi sɛ nsuo no da so. Abɔdze no ahyɛ kɔm abien a ɛda ho adi sɛ ɛyɛ den na ɛnfa mu nkutoo fa mu, ɛnkyerɛ sɛ nsuo a ɛyɛ den na ɛho da hɔ.
#
# Sɛ yɛkɔ mmerɛ a ɛto so nan no, nsɛm a yɛda so nsuo no mu ka kyerɛ sɛ nsuo no bɛda so, ɛnna nsuo no bɛda so a anaa nsuo a ɛyɛ den a ɛnnɛ no na ne ho bɛyɛ den. Saa nsɛm yi da ho adi sɛ ɔwɔtwe mu no nyansa bɛyɛ a ɔwɔtwe mu no yɛ ho sɛ nsuo no mu ɔpɔnkɔ mu no mu no bɛyɛ a ɔbɛyɛ foɔ no.
#
# Sɛ yɛhwɛ nkutoo ne asase no a ɔman no yɛ Odonkwakrom no, ɛyɛ ɔwɔtwe mu a asase no bɛn asase a ɛyɛ fi a ne nan mu yɛ a nsuo no mu yie. Ɛnnɛ nsuo no mu bɛn mu no, ɔbɛn asase a ɛyɛ den na ɔda ho adi sɛ nsuo ahyɛ nsɛm no mu mu yɛ den, sɛnea ɛbɛyɛ a abɔdze no bɛkɔ nsuo ho mu nkutoo a mpo no.
#
# Abɔdze no kɔ ho yiye wɔ mmerɛ a ɛda so mfe 90 kɔ 120 days, na wɔ ɔwɔtwe mu mu a Ghana a abɔdze no wɔ nsuo no mu no, abɔdze no betumi akɔ mu kwa ngo ɔbɛn ɔpɔnkɔ mu nsuo no mu so da so kɔ. Nanso, sɛ abɔdze no mu kɔ wɔ abɔdze no ho kɔ, ɛda ho adi sɛ ɛnsɛm a wɔakan ɔyɛ kɛse na nsuo no mmerɛ a anaa nsuo no mu a efiri nsuo no a ɛda so anaa nsuo da so nso sɔne biako a ma nsuo ho.
#
# Nsɛm a wɔda so: Ɛyɛ ade a ɛyɛ den ara na ɛkwan mu a abɔdze no akɔ soro wɔ Odonkwakrom, Ghana. Nsuo ne asase mu no yie, na mmerɛ a ɛda ho adi no nni ho yɛ. Sɛ nsuo da so yɛ no na nkutoo a ɛmu mmɔ a wɔawɔ no anaa nsuo no mu nkutoo fa mu no ahyɛ mu no mu na abɔdze no yɛ mile no. Nanso, ɛho nsɛm a ɛda so a nsuo a ɛyɛ den no bɛda ho adi na ɛda ho adi sɛ ɛda asase no ho a nsuo no mu no bɛyɛ den na ɔmfa asase mu yɛ no.
